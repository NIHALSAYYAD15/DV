# %% [markdown]
# Experiment No. 08

# %% [markdown]
# Implementation of data over time (Temporal) - based graphs and charts –Line chart. Candlestick

# %% [markdown]
# ### 1. Line chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data generation
np.random.seed(0)
dates = pd.date_range('2024-01-01', periods=50)
data = pd.DataFrame(np.random.randn(50, 4), index=dates, columns=list('ABCD'))

# Line Chart
plt.figure(figsize=(10, 6))
data.plot(kind='line')
plt.title('Line Chart')
plt.xlabel('Date')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### 2. Candlestick

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go

# Sample data generation
np.random.seed(0)
dates = pd.date_range('2024-01-01', periods=50)
data = pd.DataFrame(np.random.randn(50, 4), index=dates, columns=list('ABCD'))

# Candlestick Chart
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['A'],
                high=data['B'],
                low=data['C'],
                close=data['D'])])

fig.update_layout(title='Candlestick Chart',
                  xaxis_title='Date',
                  yaxis_title='Price')

fig.show()

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go

# Load data from CSV
data = pd.read_csv('Data/data7.csv', index_col=0, parse_dates=True)

# Candlestick Chart
fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['A'],
                high=data['B'],
                low=data['C'],
                close=data['D'])])

fig.update_layout(title='Candlestick Chart',
                  xaxis_title='Date',
                  yaxis_title='Price')

fig.show()
