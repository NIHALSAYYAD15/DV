# %% [markdown]
# Experiment No. 01

# %% [markdown]
# Implementation of comparison - based graphs and charts – Bar, column.

# %% [markdown]
# ### 1. Bar:

# %%
import matplotlib.pyplot as plt

categories = ['Category 1', 'Category 2', 'Category 3']
values = [10, 15, 8]

plt.barh(categories, values, color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Comparison')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Data/data1.csv'  
data = pd.read_csv(file_path)

# Extract categories and values
categories = data['Category']
values = data['Value']

# Create the bar chart
plt.barh(categories, values, color='skyblue')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Bar Chart Comparison')
plt.show()

# %% [markdown]
# ### 2. column:

# %%
import matplotlib.pyplot as plt

categories = ['Category 1', 'Category 2', 'Category 3']
values = [10, 15, 8]

plt.bar(categories, values, color='lightgreen')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Column Chart Comparison')
plt.show()
