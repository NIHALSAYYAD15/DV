# %% [markdown]
# Experiment No. 03

# %% [markdown]
# Implementation of correlation - based graphs and charts – Bubble, scatter.

# %% [markdown]
# ### 1. Bubble:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating a simple dataset
np.random.seed(0)
size = 30
x = np.random.rand(size)
y = 2 * x + 1 + 0.1 * np.random.randn(size)  # y is correlated with x
z = np.random.rand(size)  # z is another variable

# %%
# Bubble Chart with Color
plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=z * 100, alpha=0.7, edgecolors="grey", linewidth=0.5)
plt.title('Bubble Chart - Correlation between x, y, and bubble size')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar(label='Bubble Size')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
data = pd.read_csv('Data/data3.csv')

# Extract columns for x, y, z (bubble size)
x = data['x']
y = data['y']
z = data['z']

# Plotting the bubble chart
plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=z * 100, alpha=0.7, edgecolors="grey", linewidth=0.5)
plt.title('Bubble Chart - Correlation between x, y, and bubble size')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar(label='Bubble Size')
plt.show()

# %% [markdown]
# ### 2. scatter:

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=z, alpha=0.7, edgecolors="grey", linewidth=0.5)
plt.title('Scatter Plot - Correlation between x, y, and color')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar(label='Color')
plt.show()

# %%
import numpy as np
import pandas as pd

# Generating a simple dataset
np.random.seed(0)
size = 30
x = np.random.rand(size)
y = 2 * x + 1 + 0.1 * np.random.randn(size)  # y is correlated with x
z = np.random.rand(size)  # z is another variable

# Create a DataFrame
data = pd.DataFrame({
    'x': x,
    'y': y,
    'z': z
})

# Save the DataFrame to a CSV file
csv_file = 'Data/data3.csv'
data.to_csv(csv_file, index=False)

csv_file
# Out:
# 'Data/data3.csv'
